# %%
import pandas as pd

# Assuming your file is named "data.csv.txt" in the current directory /resources/sb_ca2022_all_34_csv_v1.txt
file_path = "resources/sb_ca2022_all_34_csv_v1.txt"

# Read the CSV file
df = pd.read_csv(file_path)

# Now you can work with the data in 'df'

# %%
df
# Out:
#        County Code^District Code^School Code^Filler^Test Year^Student Group ID^Test Type^Total Tested at Reporting Level^Total Tested with Scores at Reporting Level^Grade^Test ID^Students Enrolled^Students Tested^Mean Scale Score^Percentage Standard Exceeded^Percentage Standard Met^Percentage Standard Met and Above^Percentage Standard Nearly Met^Percentage Standard Not Met^Students with Scores^Area 1 Percentage Above Standard^Area 1 Percentage Near Standard^Area 1 Percentage Below Standard^Area 2 Percentage Above Standard^Area 2 Percentage Near Standard^Area 2 Percentage Below Standard^Area 3 Percentage Above Standard^Area 3 Percentage Near Standard^Area 3 Percentage Below Standard^Area 4 Percentage Above Standard^Area 4 Percentage Near Standard^Area 4 Percentage Below Standard^Type ID
# 0       34^00000^0000000^^2022^1^B^119323^119137^3^1^1...
# 1       34^00000^0000000^^2022^3^B^61267^61174^3^1^914...
# 2       34^00000^0000000^^2022^4^B^57953^57860^3^1^873...
# 3       34^00000^0000000^^2022^6^B^98630^98472^3^1^137...
# 4       34^00000^0000000^^2022^7^B^3978^3974^3^1^868^8...
# ...                                                   ...
# 152422  34^77040^5430020^^2022^121^B^0^0^13^2^*^0^^^^^...
# 152423  34^77040^5430020^^2022^128^B^0^0^13^2^*^0^^^^^...
# 152424  34^77040^5430020^^2022^180^B^0^0^13^2^*^0^^^^^...
# 152425  34^77040^5430020^^2022^224^B^0^0^13^2^*^0^^^^^...
# 152426  34^77040^5430020^^2022^241^B^0^0^13^2^*^0^^^^^...
#
# [152427 rows x 1 columns]

# %%
df.head()
# Out:
#   County Code^District Code^School Code^Filler^Test Year^Student Group ID^Test Type^Total Tested at Reporting Level^Total Tested with Scores at Reporting Level^Grade^Test ID^Students Enrolled^Students Tested^Mean Scale Score^Percentage Standard Exceeded^Percentage Standard Met^Percentage Standard Met and Above^Percentage Standard Nearly Met^Percentage Standard Not Met^Students with Scores^Area 1 Percentage Above Standard^Area 1 Percentage Near Standard^Area 1 Percentage Below Standard^Area 2 Percentage Above Standard^Area 2 Percentage Near Standard^Area 2 Percentage Below Standard^Area 3 Percentage Above Standard^Area 3 Percentage Near Standard^Area 3 Percentage Below Standard^Area 4 Percentage Above Standard^Area 4 Percentage Near Standard^Area 4 Percentage Below Standard^Type ID
# 0  34^00000^0000000^^2022^1^B^119323^119137^3^1^1...
# 1  34^00000^0000000^^2022^3^B^61267^61174^3^1^914...
# 2  34^00000^0000000^^2022^4^B^57953^57860^3^1^873...
# 3  34^00000^0000000^^2022^6^B^98630^98472^3^1^137...
# 4  34^00000^0000000^^2022^7^B^3978^3974^3^1^868^8...

# %%
df = pd.read_csv('resources/sb_ca2022_all_34_csv_v1.txt', sep='^')

# %%
df.head(15)
# Out:
#     County Code  District Code  School Code  Filler  Test Year  \
# 0            34              0            0     NaN       2022
# 1            34              0            0     NaN       2022
# 2            34              0            0     NaN       2022
# 3            34              0            0     NaN       2022
# 4            34              0            0     NaN       2022
# 5            34              0            0     NaN       2022
# 6            34              0            0     NaN       2022
# 7            34              0            0     NaN       2022
# 8            34              0            0     NaN       2022
# 9            34              0            0     NaN       2022
# 10           34              0            0     NaN       2022
# 11           34              0            0     NaN       2022
# 12           34              0            0     NaN       2022
# 13           34              0            0     NaN       2022
# 14           34              0            0     NaN       2022
#
#     Student Group ID Test Type Total Tested at Reporting Level  \
# 0                  1         B                          119323
# 1                  3         B                           61267
# 2                  4         B                           57953
# 3                  6         B                           98630
# 4                  7         B                            3978
# 5                  8         B                           16725
# 6                 28         B                             467
# 7                 29         B                          118856
# 8                 31         B                           66574
# 9                 50         B                            1336
# 10                51         B                          117987
# 11                52         B                            3068
# 12                53         B                          116255
# 13                74         B                           12634
# 14                75         B                             567
#
#    Total Tested with Scores at Reporting Level  Grade  ...  \
# 0                                       119137      3  ...
# 1                                        61174      3  ...
# 2                                        57860      3  ...
# 3                                        98472      3  ...
# 4                                         3974      3  ...
# 5                                        16708      3  ...
# 6                                          467      3  ...
# 7                                       118670      3  ...
# 8                                        66444      3  ...
# 9                                         1335      3  ...
# 10                                      117802      3  ...
# 11                                        3054      3  ...
# 12                                      116083      3  ...
# 13                                       12604      3  ...
# 14                                         567      3  ...
#
#     Area 2 Percentage Above Standard Area 2 Percentage Near Standard  \
# 0                              13.83                           48.11
# 1                              11.29                           46.84
# 2                              16.47                           49.45
# 3                              16.49                           50.32
# 4                              28.97                           51.17
# 5                              32.51                           57.61
# 6                               7.69                           40.38
# 7                              13.85                           48.13
# 8                               7.72                           43.72
# 9                              11.37                           48.34
# 10                             13.86                           48.11
# 11                              3.31                           38.30
# 12                             14.13                           48.39
# 13                              5.42                           40.28
# 14                              7.69                           36.92
#
#    Area 2 Percentage Below Standard Area 3 Percentage Above Standard  \
# 0                             38.06                            11.23
# 1                             41.87                            10.45
# 2                             34.09                            12.04
# 3                             33.19                            13.15
# 4                             19.86                            20.33
# 5                              9.88                            19.86
# 6                             51.92                             5.77
# 7                             38.02                            11.24
# 8                             48.57                             7.30
# 9                             40.28                             8.53
# 10                            38.04                            11.26
# 11                            58.39                             5.99
# 12                            37.48                            11.38
# 13                            54.29                             6.25
# 14                            55.38                             3.08
#
#    Area 3 Percentage Near Standard Area 3 Percentage Below Standard  \
# 0                            70.95                            17.82
# 1                            70.96                            18.59
# 2                            70.94                            17.02
# 3                            71.56                            15.29
# 4                            71.61                             8.06
# 5                            74.38                             5.75
# 6                            69.23                            25.00
# 7                            70.96                            17.80
# 8                            70.30                            22.40
# 9                            74.41                            17.06
# 10                           70.91                            17.83
# 11                           64.46                            29.55
# 12                           71.14                            17.48
# 13                           67.74                            26.01
# 14                           67.69                            29.23
#
#    Area 4 Percentage Above Standard Area 4 Percentage Near Standard  \
# 0                             14.57                           59.79
# 1                             13.60                           58.36
# 2                             15.59                           61.28
# 3                             17.22                           61.09
# 4                             27.22                           60.51
# 5                             29.45                           64.52
# 6                              3.85                           59.62
# 7                             14.60                           59.79
# 8                              8.50                           58.10
# 9                              9.00                           65.40
# 10                            14.64                           59.72
# 11                             6.40                           50.21
# 12                            14.81                           60.07
# 13                             6.08                           55.52
# 14                             9.23                           52.31
#
#    Area 4 Percentage Below Standard Type ID
# 0                             25.64       5
# 1                             28.04       5
# 2                             23.13       5
# 3                             21.69       5
# 4                             12.27       5
# 5                              6.03       5
# 6                             36.54       5
# 7                             25.60       5
# 8                             33.40       5
# 9                             25.59       5
# 10                            25.64       5
# 11                            43.39       5
# 12                            25.12       5
# 13                            38.40       5
# 14                            38.46       5
#
# [15 rows x 33 columns]

# %%
df1=df.dropna(how='all',axis=1)
df1
# Out:
#         County Code  District Code  School Code  Test Year  Student Group ID  \
# 0                34              0            0       2022                 1
# 1                34              0            0       2022                 3
# 2                34              0            0       2022                 4
# 3                34              0            0       2022                 6
# 4                34              0            0       2022                 7
# ...             ...            ...          ...        ...               ...
# 152422           34          77040      5430020       2022               121
# 152423           34          77040      5430020       2022               128
# 152424           34          77040      5430020       2022               180
# 152425           34          77040      5430020       2022               224
# 152426           34          77040      5430020       2022               241
#
#        Test Type Total Tested at Reporting Level  \
# 0              B                          119323
# 1              B                           61267
# 2              B                           57953
# 3              B                           98630
# 4              B                            3978
# ...          ...                             ...
# 152422         B                               0
# 152423         B                               0
# 152424         B                               0
# 152425         B                               0
# 152426         B                               0
#
#        Total Tested with Scores at Reporting Level  Grade  Test ID  ...  \
# 0                                           119137      3        1  ...
# 1                                            61174      3        1  ...
# 2                                            57860      3        1  ...
# 3                                            98472      3        1  ...
# 4                                             3974      3        1  ...
# ...                                            ...    ...      ...  ...
# 152422                                           0     13        2  ...
# 152423                                           0     13        2  ...
# 152424                                           0     13        2  ...
# 152425                                           0     13        2  ...
# 152426                                           0     13        2  ...
#
#        Area 2 Percentage Above Standard Area 2 Percentage Near Standard  \
# 0                                 13.83                           48.11
# 1                                 11.29                           46.84
# 2                                 16.47                           49.45
# 3                                 16.49                           50.32
# 4                                 28.97                           51.17
# ...                                 ...                             ...
# 152422                              NaN                             NaN
# 152423                              NaN                             NaN
# 152424                              NaN                             NaN
# 152425                              NaN                             NaN
# 152426                              NaN                             NaN
#
#        Area 2 Percentage Below Standard Area 3 Percentage Above Standard  \
# 0                                 38.06                            11.23
# 1                                 41.87                            10.45
# 2                                 34.09                            12.04
# 3                                 33.19                            13.15
# 4                                 19.86                            20.33
# ...                                 ...                              ...
# 152422                              NaN                              NaN
# 152423                              NaN                              NaN
# 152424                              NaN                              NaN
# 152425                              NaN                              NaN
# 152426                              NaN                              NaN
#
#        Area 3 Percentage Near Standard Area 3 Percentage Below Standard  \
# 0                                70.95                            17.82
# 1                                70.96                            18.59
# 2                                70.94                            17.02
# 3                                71.56                            15.29
# 4                                71.61                             8.06
# ...                                ...                              ...
# 152422                             NaN                              NaN
# 152423                             NaN                              NaN
# 152424                             NaN                              NaN
# 152425                             NaN                              NaN
# 152426                             NaN                              NaN
#
#        Area 4 Percentage Above Standard Area 4 Percentage Near Standard  \
# 0                                 14.57                           59.79
# 1                                 13.60                           58.36
# 2                                 15.59                           61.28
# 3                                 17.22                           61.09
# 4                                 27.22                           60.51
# ...                                 ...                             ...
# 152422                              NaN                             NaN
# 152423                              NaN                             NaN
# 152424                              NaN                             NaN
# 152425                              NaN                             NaN
# 152426                              NaN                             NaN
#
#        Area 4 Percentage Below Standard Type ID
# 0                                 25.64       5
# 1                                 28.04       5
# 2                                 23.13       5
# 3                                 21.69       5
# 4                                 12.27       5
# ...                                 ...     ...
# 152422                              NaN       7
# 152423                              NaN       7
# 152424                              NaN       7
# 152425                              NaN       7
# 152426                              NaN       7
#
# [152427 rows x 32 columns]

# %%
df2=df1.dropna()
df2
# Out:
#         County Code  District Code  School Code  Test Year  Student Group ID  \
# 0                34              0            0       2022                 1
# 1                34              0            0       2022                 3
# 2                34              0            0       2022                 4
# 3                34              0            0       2022                 6
# 4                34              0            0       2022                 7
# ...             ...            ...          ...        ...               ...
# 152268           34          76505      6112643       2022               223
# 152269           34          76505      6112643       2022               224
# 152270           34          76505      6112643       2022               226
# 152271           34          76505      6112643       2022               227
# 152272           34          76505      6112643       2022               241
#
#        Test Type Total Tested at Reporting Level  \
# 0              B                          119323
# 1              B                           61267
# 2              B                           57953
# 3              B                           98630
# 4              B                            3978
# ...          ...                             ...
# 152268         B                               4
# 152269         B                              26
# 152270         B                              36
# 152271         B                               5
# 152272         B                             388
#
#        Total Tested with Scores at Reporting Level  Grade  Test ID  ...  \
# 0                                           119137      3        1  ...
# 1                                            61174      3        1  ...
# 2                                            57860      3        1  ...
# 3                                            98472      3        1  ...
# 4                                             3974      3        1  ...
# ...                                            ...    ...      ...  ...
# 152268                                           4      8        2  ...
# 152269                                          26      8        2  ...
# 152270                                          36      8        2  ...
# 152271                                           5      8        2  ...
# 152272                                         388      8        2  ...
#
#        Area 2 Percentage Above Standard Area 2 Percentage Near Standard  \
# 0                                 13.83                           48.11
# 1                                 11.29                           46.84
# 2                                 16.47                           49.45
# 3                                 16.49                           50.32
# 4                                 28.97                           51.17
# ...                                 ...                             ...
# 152268                                *                               *
# 152269                                *                               *
# 152270                                *                               *
# 152271                                *                               *
# 152272                            14.78                           54.19
#
#        Area 2 Percentage Below Standard Area 3 Percentage Above Standard  \
# 0                                 38.06                            11.23
# 1                                 41.87                            10.45
# 2                                 34.09                            12.04
# 3                                 33.19                            13.15
# 4                                 19.86                            20.33
# ...                                 ...                              ...
# 152268                                *                                *
# 152269                                *                                *
# 152270                                *                                *
# 152271                                *                                *
# 152272                            31.03                            15.76
#
#        Area 3 Percentage Near Standard Area 3 Percentage Below Standard  \
# 0                                70.95                            17.82
# 1                                70.96                            18.59
# 2                                70.94                            17.02
# 3                                71.56                            15.29
# 4                                71.61                             8.06
# ...                                ...                              ...
# 152268                               *                                *
# 152269                               *                                *
# 152270                               *                                *
# 152271                               *                                *
# 152272                           58.13                            26.11
#
#        Area 4 Percentage Above Standard Area 4 Percentage Near Standard  \
# 0                                 14.57                           59.79
# 1                                 13.60                           58.36
# 2                                 15.59                           61.28
# 3                                 17.22                           61.09
# 4                                 27.22                           60.51
# ...                                 ...                             ...
# 152268                                *                               *
# 152269                                *                               *
# 152270                                *                               *
# 152271                                *                               *
# 152272                             0.00                            0.00
#
#        Area 4 Percentage Below Standard Type ID
# 0                                 25.64       5
# 1                                 28.04       5
# 2                                 23.13       5
# 3                                 21.69       5
# 4                                 12.27       5
# ...                                 ...     ...
# 152268                                *      10
# 152269                                *      10
# 152270                                *      10
# 152271                                *      10
# 152272                             0.00      10
#
# [112622 rows x 32 columns]

# %%
# Display the number of rows and columns
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

# Display data types of columns
print("\nData types of columns:")
print(df.dtypes)

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Number of rows: 152427
# Number of columns: 33
#
# Data types of columns:
# County Code                                      int64
# District Code                                    int64
# School Code                                      int64
# Filler                                         float64
# Test Year                                        int64
# Student Group ID                                 int64
# Test Type                                       object
# Total Tested at Reporting Level                 object
# Total Tested with Scores at Reporting Level     object
# Grade                                            int64
# Test ID                                          int64
# Students Enrolled                               object
# Students Tested                                 object
# Mean Scale Score                                object
# Percentage Standard Exceeded                    object
# Percentage Standard Met                         object
# Percentage Standard Met and Above               object
# Percentage Standard Nearly Met                  object
# Percentage Standard Not Met                     object
# Students with Scores                            object
# Area 1 Percentage Above Standard                object
# Area 1 Percentage Near Standard                 object
# Area 1 Percentage Below Standard                object
# Area 2 Percentage Above Standard                object
# Area 2 Percentage Near Standard                 object
# Area 2 Percentage Below Standard                object
# Area 3 Percentage Above Standard                object
# Area 3 Percentage Near Standard                 object
# Area 3 Percentage Below Standard                object
# Area 4 Percentage Above Standard                object
# Area 4 Percentage Near Standard                 object
# Area 4 Percentage Below Standard                object
# Type ID                                          int64
# dtype: object
#
# Missing values:
# County Code                                         0
# District Code                                       0
# School Code                                         0
# Filler                                         152427
# Test Year                                           0
# Student Group ID                                    0
# Test Type                                           0
# Total Tested at Reporting Level                     0
# Total Tested with Scores at Reporting Level         0
# Grade                                               0
# Test ID                                             0
# Students Enrolled                                   0
# Students Tested                                     0
# Mean Scale Score                                39805
# Percentage Standard Exceeded                     3974
# Percentage Standard Met                          3974
# Percentage Standard Met and Above                3974
# Percentage Standard Nearly Met                   3974
# Percentage Standard Not Met                      3974
# Students with Scores                                0
# Area 1 Percentage Above Standard                 3974
# Area 1 Percentage Near Standard                  3974
# Area 1 Percentage Below Standard                 3974
# Area 2 Percentage Above Standard                 3974
# Area 2 Percentage Near Standard                  3974
# Area 2 Percentage Below Standard                 3974
# Area 3 Percentage Above Standard                 3974
# Area 3 Percentage Near Standard                  3974
# Area 3 Percentage Below Standard                 3974
# Area 4 Percentage Above Standard                 3974
# Area 4 Percentage Near Standard                  3974
# Area 4 Percentage Below Standard                 3974
# Type ID                                             0
# dtype: int64

# %%
df
# Out:
#         County Code  District Code  School Code  Filler  Test Year  \
# 0                34              0            0     NaN       2022
# 1                34              0            0     NaN       2022
# 2                34              0            0     NaN       2022
# 3                34              0            0     NaN       2022
# 4                34              0            0     NaN       2022
# ...             ...            ...          ...     ...        ...
# 152422           34          77040      5430020     NaN       2022
# 152423           34          77040      5430020     NaN       2022
# 152424           34          77040      5430020     NaN       2022
# 152425           34          77040      5430020     NaN       2022
# 152426           34          77040      5430020     NaN       2022
#
#         Student Group ID Test Type Total Tested at Reporting Level  \
# 0                      1         B                          119323
# 1                      3         B                           61267
# 2                      4         B                           57953
# 3                      6         B                           98630
# 4                      7         B                            3978
# ...                  ...       ...                             ...
# 152422               121         B                               0
# 152423               128         B                               0
# 152424               180         B                               0
# 152425               224         B                               0
# 152426               241         B                               0
#
#        Total Tested with Scores at Reporting Level  Grade  ...  \
# 0                                           119137      3  ...
# 1                                            61174      3  ...
# 2                                            57860      3  ...
# 3                                            98472      3  ...
# 4                                             3974      3  ...
# ...                                            ...    ...  ...
# 152422                                           0     13  ...
# 152423                                           0     13  ...
# 152424                                           0     13  ...
# 152425                                           0     13  ...
# 152426                                           0     13  ...
#
#         Area 2 Percentage Above Standard Area 2 Percentage Near Standard  \
# 0                                  13.83                           48.11
# 1                                  11.29                           46.84
# 2                                  16.47                           49.45
# 3                                  16.49                           50.32
# 4                                  28.97                           51.17
# ...                                  ...                             ...
# 152422                               NaN                             NaN
# 152423                               NaN                             NaN
# 152424                               NaN                             NaN
# 152425                               NaN                             NaN
# 152426                               NaN                             NaN
#
#        Area 2 Percentage Below Standard Area 3 Percentage Above Standard  \
# 0                                 38.06                            11.23
# 1                                 41.87                            10.45
# 2                                 34.09                            12.04
# 3                                 33.19                            13.15
# 4                                 19.86                            20.33
# ...                                 ...                              ...
# 152422                              NaN                              NaN
# 152423                              NaN                              NaN
# 152424                              NaN                              NaN
# 152425                              NaN                              NaN
# 152426                              NaN                              NaN
#
#        Area 3 Percentage Near Standard Area 3 Percentage Below Standard  \
# 0                                70.95                            17.82
# 1                                70.96                            18.59
# 2                                70.94                            17.02
# 3                                71.56                            15.29
# 4                                71.61                             8.06
# ...                                ...                              ...
# 152422                             NaN                              NaN
# 152423                             NaN                              NaN
# 152424                             NaN                              NaN
# 152425                             NaN                              NaN
# 152426                             NaN                              NaN
#
#        Area 4 Percentage Above Standard Area 4 Percentage Near Standard  \
# 0                                 14.57                           59.79
# 1                                 13.60                           58.36
# 2                                 15.59                           61.28
# 3                                 17.22                           61.09
# 4                                 27.22                           60.51
# ...                                 ...                             ...
# 152422                              NaN                             NaN
# 152423                              NaN                             NaN
# 152424                              NaN                             NaN
# 152425                              NaN                             NaN
# 152426                              NaN                             NaN
#
#        Area 4 Percentage Below Standard Type ID
# 0                                 25.64       5
# 1                                 28.04       5
# 2                                 23.13       5
# 3                                 21.69       5
# 4                                 12.27       5
# ...                                 ...     ...
# 152422                              NaN       7
# 152423                              NaN       7
# 152424                              NaN       7
# 152425                              NaN       7
# 152426                              NaN       7
#
# [152427 rows x 33 columns]

# %%
# Convert columns to numeric data types
numeric_columns = [
    'Total Tested at Reporting Level',
    'Total Tested with Scores at Reporting Level',
    'Students Enrolled',
    'Students Tested',
    'Mean Scale Score',
    'Percentage Standard Exceeded',
    'Percentage Standard Met',
    'Percentage Standard Met and Above',
    'Percentage Standard Nearly Met',
    'Percentage Standard Not Met',
    'Students with Scores',
    'Area 1 Percentage Above Standard',
    'Area 1 Percentage Near Standard',
    'Area 1 Percentage Below Standard',
    'Area 2 Percentage Above Standard',
    'Area 2 Percentage Near Standard',
    'Area 2 Percentage Below Standard',
    'Area 3 Percentage Above Standard',
    'Area 3 Percentage Near Standard',
    'Area 3 Percentage Below Standard',
    'Area 4 Percentage Above Standard',
    'Area 4 Percentage Near Standard',
    'Area 4 Percentage Below Standard'
]

# Convert columns to numeric data types
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Verify the data types after conversion
print(df.dtypes)
# Out:
# County Code                                      int64
# District Code                                    int64
# School Code                                      int64
# Filler                                         float64
# Test Year                                        int64
# Student Group ID                                 int64
# Test Type                                       object
# Total Tested at Reporting Level                float64
# Total Tested with Scores at Reporting Level    float64
# Grade                                            int64
# Test ID                                          int64
# Students Enrolled                              float64
# Students Tested                                float64
# Mean Scale Score                               float64
# Percentage Standard Exceeded                   float64
# Percentage Standard Met                        float64
# Percentage Standard Met and Above              float64
# Percentage Standard Nearly Met                 float64
# Percentage Standard Not Met                    float64
# Students with Scores                           float64
# Area 1 Percentage Above Standard               float64
# Area 1 Percentage Near Standard                float64
# Area 1 Percentage Below Standard               float64
# Area 2 Percentage Above Standard               float64
# Area 2 Percentage Near Standard                float64
# Area 2 Percentage Below Standard               float64
# Area 3 Percentage Above Standard               float64
# Area 3 Percentage Near Standard                float64
# Area 3 Percentage Below Standard               float64
# Area 4 Percentage Above Standard               float64
# Area 4 Percentage Near Standard                float64
# Area 4 Percentage Below Standard               float64
# Type ID                                          int64
# dtype: object

# %%
import pandas as pd
import sqlite3

# %%
df9 =pd.DataFrame({
    "ID": [1,2],
    "Name": ["Nohan", "Julian"]
})

# %%
df9
# Out:
#    ID    Name
# 0   1   Nohan
# 1   2  Julian

# %%
conn = sqlite3.connect("newdemo.sqlite")

# %%
df2.to_sql(name = "testscoredb", con = conn)
# Out:
# 112622

# %%
df2
# Out:
#         County Code  District Code  School Code  Test Year  Student Group ID  \
# 0                34              0            0       2022                 1
# 1                34              0            0       2022                 3
# 2                34              0            0       2022                 4
# 3                34              0            0       2022                 6
# 4                34              0            0       2022                 7
# ...             ...            ...          ...        ...               ...
# 152268           34          76505      6112643       2022               223
# 152269           34          76505      6112643       2022               224
# 152270           34          76505      6112643       2022               226
# 152271           34          76505      6112643       2022               227
# 152272           34          76505      6112643       2022               241
#
#        Test Type Total Tested at Reporting Level  \
# 0              B                          119323
# 1              B                           61267
# 2              B                           57953
# 3              B                           98630
# 4              B                            3978
# ...          ...                             ...
# 152268         B                               4
# 152269         B                              26
# 152270         B                              36
# 152271         B                               5
# 152272         B                             388
#
#        Total Tested with Scores at Reporting Level  Grade  Test ID  ...  \
# 0                                           119137      3        1  ...
# 1                                            61174      3        1  ...
# 2                                            57860      3        1  ...
# 3                                            98472      3        1  ...
# 4                                             3974      3        1  ...
# ...                                            ...    ...      ...  ...
# 152268                                           4      8        2  ...
# 152269                                          26      8        2  ...
# 152270                                          36      8        2  ...
# 152271                                           5      8        2  ...
# 152272                                         388      8        2  ...
#
#        Area 2 Percentage Above Standard Area 2 Percentage Near Standard  \
# 0                                 13.83                           48.11
# 1                                 11.29                           46.84
# 2                                 16.47                           49.45
# 3                                 16.49                           50.32
# 4                                 28.97                           51.17
# ...                                 ...                             ...
# 152268                                *                               *
# 152269                                *                               *
# 152270                                *                               *
# 152271                                *                               *
# 152272                            14.78                           54.19
#
#        Area 2 Percentage Below Standard Area 3 Percentage Above Standard  \
# 0                                 38.06                            11.23
# 1                                 41.87                            10.45
# 2                                 34.09                            12.04
# 3                                 33.19                            13.15
# 4                                 19.86                            20.33
# ...                                 ...                              ...
# 152268                                *                                *
# 152269                                *                                *
# 152270                                *                                *
# 152271                                *                                *
# 152272                            31.03                            15.76
#
#        Area 3 Percentage Near Standard Area 3 Percentage Below Standard  \
# 0                                70.95                            17.82
# 1                                70.96                            18.59
# 2                                70.94                            17.02
# 3                                71.56                            15.29
# 4                                71.61                             8.06
# ...                                ...                              ...
# 152268                               *                                *
# 152269                               *                                *
# 152270                               *                                *
# 152271                               *                                *
# 152272                           58.13                            26.11
#
#        Area 4 Percentage Above Standard Area 4 Percentage Near Standard  \
# 0                                 14.57                           59.79
# 1                                 13.60                           58.36
# 2                                 15.59                           61.28
# 3                                 17.22                           61.09
# 4                                 27.22                           60.51
# ...                                 ...                             ...
# 152268                                *                               *
# 152269                                *                               *
# 152270                                *                               *
# 152271                                *                               *
# 152272                             0.00                            0.00
#
#        Area 4 Percentage Below Standard Type ID
# 0                                 25.64       5
# 1                                 28.04       5
# 2                                 23.13       5
# 3                                 21.69       5
# 4                                 12.27       5
# ...                                 ...     ...
# 152268                                *      10
# 152269                                *      10
# 152270                                *      10
# 152271                                *      10
# 152272                             0.00      10
#
# [112622 rows x 32 columns]
